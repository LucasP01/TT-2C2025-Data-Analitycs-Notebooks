# %% [markdown]
# # Actividades

# %% [markdown]
# ## Actividad 1

# %% [markdown]
#   Creá tu propio bloque de texto. Utiliza:
#   - formatos de texto
#   - links
#   - al menos una imagen de tu carpeta Drive

# %% [markdown]
# #Bienvenidos a mi texto!
# ## ES una prueba random
# ### Esto es un subtitulo
# **Este es mi primer texto??**
# *Si, efectivamente es mi primer texto*
# -  IDK
# 1. Si, es mi primer texto
# 2. Efectivamente lo es?
# 3. Siiii
#
# > Identacion
# >> doble identacion
#
# [Link a algun lado](https://www.google.com.ar/maps)
#
# ``` codigo ```
#
# $y=x^2$
#
# $e^{i\pi} + 1 = 0$
#
# $e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$
#
# $\frac{n!}{k!(n-k)!} = {n \choose k}$
#
#
# First column name  | Second column name
# -------------------|------------------
# Row 1, Col 1       | Row 1, Col 2
# Row 2, Col 1       | Row 2, Col 2
#
#
# ---
#
#
# <img src="https://drive.google.com/uc?id={1YZ0fvWw54q5_TT3o5EFZr7E0MEqz8vdC}">

# %% [markdown]
# ## Actividad 2

# %% [markdown]
# Creá un bloque de código con un programa que pida un número por teclado, y responda si es par o impar. Ejecutalo.

# %%
print("Bienvenido al programa numero 1: ")
numero = int(input("Ingrese un numero: "))
if numero % 2 == 0:
  print("El numero es par")
else:
  print("El numero es impar")
# Out:
# Bienvenido al programa numero 1:
# Ingrese un numero: 10
# El numero es par

# %%
print("Par" if int(input("Ingrese un numero: ")) % 2 == 0 else "Impar")
# Out:
# Ingrese un numero: 10
# Par
